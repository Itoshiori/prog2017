# %% [markdown]
# import turtle
# t = turtle.Turtle()
#
# t.home()
# t.clear()
#
# for i in range(4):
#   t.forward(200)
#   t.left(90)
#   t.up()
#
#
# print('hello')
#
#
#
#
# def func():
#   i = 3
#   return i
#
# func()
#
#
# def func(v):
#   i = v + 3
#   return i
#
#
# def tatal(n):
#   s = 0
#   for x in range(1,n+1):
#     s += x
#   return s
#
# #import turtle
# #t = turtle.Turtle()
#
# t.home()
# t.clear()
#
#
# def rect(x, y, a):
#   t.up()
#   t.home()
#   t.forward(x)
#   t.left(90)
#   t.forward(y)
#   t.down()
#   for i in range(4):
#     t.forward(a)
#     t.left(-90)
#
# def yline(x, y, a):
#   t.up()
#   t.home()
#   t.forward(x)
#   t.left(90)
#   t.forward(y)
#   t.down()
#   t.forward(a)
#
# #import turtle
# #t = turtle.Turtle()
#
# t.home()
# t.clear()
#
# for j in range(2):
#   for i in range(4):
#     t.forward(100)
#     t.left(90)
#
#   t.left(90)
#   t.forward(120)
#
#   for i in range(6):
#     t.forward(100)
#     t.forward(-100)
#     t.left(-90)
#     t.forward(20)
#     t.left(90)
#
#   t.forward(-120)
#   t.left(-90)
#   t.forward(-240)
#
# print('hello')
#
# #import turtle
# #t = turtle.Turtle()
#
# t.home()
# t.clear()
#
# t.circle()
#
#
# ↓丸書く
# def circle(x,y,r):
#   t.up()
#   t.home()
#   t.forward(x)
#   t.left(90)
#   t.forward(y)
#   t.forward(r)
#   t.left(90)
#   t.down()
#   t.circle(r)
#
# t.clear()
# circle(100,100,50)
#
# ↓４つ丸描く
# def circle(x,y,r):
#   t.up()
#   t.home()
#   t.forward(x)
#   t.left(90)
#   t.forward(y)
#   t.forward(r)
#   t.left(90)
#   t.down()
#   t.circle(r)
#
# t.clear()
# circle(0,100,50)
# circle(0,0,50)
# circle(100,100,50)
# circle(100,0,50)
#
#
# circle(100,-100,50)
# circle(100,-100,50)
